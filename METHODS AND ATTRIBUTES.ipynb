# %% [markdown]
# METHODS AND ATTRIBUTES

# %%
import pandas as pd

# %%
df = pd.read_csv('flights.csv')

# %%
df1 = pd.Series ([1, 2, 3, 4, 5])

# %%
df[['year', 'month', 'day']].describe()
# Out:
#            year          month            day
# count  336776.0  336776.000000  336776.000000
# mean     2013.0       6.548510      15.710787
# std         0.0       3.414457       8.768607
# min      2013.0       1.000000       1.000000
# 25%      2013.0       4.000000       8.000000
# 50%      2013.0       7.000000      16.000000
# 75%      2013.0      10.000000      23.000000
# max      2013.0      12.000000      31.000000

# %%
df.describe(include = 'int')
# Out:
#            year          month            day  sched_dep_time  sched_arr_time  \
# count  336776.0  336776.000000  336776.000000   336776.000000   336776.000000
# mean     2013.0       6.548510      15.710787     1344.254840     1536.380220
# std         0.0       3.414457       8.768607      467.335756      497.457142
# min      2013.0       1.000000       1.000000      106.000000        1.000000
# 25%      2013.0       4.000000       8.000000      906.000000     1124.000000
# 50%      2013.0       7.000000      16.000000     1359.000000     1556.000000
# 75%      2013.0      10.000000      23.000000     1729.000000     1945.000000
# max      2013.0      12.000000      31.000000     2359.000000     2359.000000
#
#               flight       distance           hour         minute
# count  336776.000000  336776.000000  336776.000000  336776.000000
# mean     1971.923620    1039.912604      13.180247      26.230100
# std      1632.471938     733.233033       4.661316      19.300846
# ...

# %%
pd

# %%
df.describe()
# Out:
#            year          month            day       dep_time  sched_dep_time  \
# count  336776.0  336776.000000  336776.000000  328521.000000   336776.000000
# mean     2013.0       6.548510      15.710787    1349.109947     1344.254840
# std         0.0       3.414457       8.768607     488.281791      467.335756
# min      2013.0       1.000000       1.000000       1.000000      106.000000
# 25%      2013.0       4.000000       8.000000     907.000000      906.000000
# 50%      2013.0       7.000000      16.000000    1401.000000     1359.000000
# 75%      2013.0      10.000000      23.000000    1744.000000     1729.000000
# max      2013.0      12.000000      31.000000    2400.000000     2359.000000
#
#            dep_delay       arr_time  sched_arr_time      arr_delay  \
# count  328521.000000  328063.000000   336776.000000  327346.000000
# mean       12.639070    1502.054999     1536.380220       6.895377
# std        40.210061     533.264132      497.457142      44.633292
# ...

# %%
df.head(10)
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
# 5  2013      1    1     554.0             558       -4.0     740.0
# 6  2013      1    1     555.0             600       -5.0     913.0
# 7  2013      1    1     557.0             600       -3.0     709.0
# 8  2013      1    1     557.0             600       -3.0     838.0
# 9  2013      1    1     558.0             600       -2.0     753.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# ...

# %%
df.nunique()
# Out:
# year                 1
# month               12
# day                 31
# dep_time          1318
# sched_dep_time    1021
# dep_delay          527
# arr_time          1411
# sched_arr_time    1163
# arr_delay          577
# carrier             16
# flight            3844
# tailnum           4043
# origin               3
# dest               105
# air_time           509
# distance           214
# hour                20
# minute              60
# time_hour         6936
# dtype: int64

# %%
df.tail()
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 336771            1634        NaN      9E    3393     NaN    JFK  DCA
# 336772            2312        NaN      9E    3525     NaN    LGA  SYR
# 336773            1330        NaN      MQ    3461  N535MQ    LGA  BNA
# 336774            1344        NaN      MQ    3572  N511MQ    LGA  CLE
# 336775            1020        NaN      MQ    3531  N839MQ    LGA  RDU
#
#         air_time  distance  hour  minute         time_hour
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 336776 entries, 0 to 336775
# Series name: year
# Non-Null Count   Dtype
# --------------   -----
# 336776 non-null  int64
# dtypes: int64(1)
# memory usage: 2.6 MB

# %%
df.describe()
# Out:
#            year          month            day       dep_time  sched_dep_time  \
# count  336776.0  336776.000000  336776.000000  328521.000000   336776.000000
# mean     2013.0       6.548510      15.710787    1349.109947     1344.254840
# std         0.0       3.414457       8.768607     488.281791      467.335756
# min      2013.0       1.000000       1.000000       1.000000      106.000000
# 25%      2013.0       4.000000       8.000000     907.000000      906.000000
# 50%      2013.0       7.000000      16.000000    1401.000000     1359.000000
# 75%      2013.0      10.000000      23.000000    1744.000000     1729.000000
# max      2013.0      12.000000      31.000000    2400.000000     2359.000000
#
#            dep_delay       arr_time  sched_arr_time      arr_delay  \
# count  328521.000000  328063.000000   336776.000000  327346.000000
# mean       12.639070    1502.054999     1536.380220       6.895377
# std        40.210061     533.264132      497.457142      44.633292
# ...

# %%
age = pd.Series([22, 23, 24, 25])
age
# Out:
# 0    22
# 1    23
# 2    24
# 3    25
# dtype: int64

# %%
age.unique()
# Out:
# array([22, 23, 24, 25], dtype=int64)

# %%
df.columns
# Out:
# Index(['year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour'],
#       dtype='object')

# %%
df.shape
# Out:
# (336776, 19)

# %%
age.shape
# Out:
# (4,)

# %%
df.values
# Out:
# array([[2013, 1, 1, ..., 5, 15, '01-01-2013 05:00'],
#        [2013, 1, 1, ..., 5, 29, '01-01-2013 05:00'],
#        [2013, 1, 1, ..., 5, 40, '01-01-2013 05:00'],
#        ...,
#        [2013, 9, 30, ..., 12, 10, '30-09-2013 12:00'],
#        [2013, 9, 30, ..., 11, 59, '30-09-2013 11:00'],
#        [2013, 9, 30, ..., 8, 40, '30-09-2013 08:00']], dtype=object)

# %% [markdown]
# Dropna method for dropping missing data

# %%
mydata = df.dropna(axis = 1)
mydata.shape
# Out:
# (336776, 13)

# %%
df.dropna()# axis = 0 means row wise drop, axis = 1, means columns wise drop

# %%
mydata = df.dropna(how = 'all')
mydata.shape
# Out:
# (336776, 19)

# %%
mydata1 = df.dropna(how = 'all')

# %%
mydata2 = df.dropna(subset = ['tailnum', 'flight'])
mydata2
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336769  2013      9   30    2349.0            2359      -10.0     325.0
# 336770  2013      9   30       NaN            1842        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
df.dropna(subset = ['carrier', 'flight'])
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
mydata2 = df[['carrier', 'flight']]

mydata2 = df[['carrier', 'flight']]# comments
mydata2
# Out:
#        carrier  flight
# 0           UA    1545
# 1           UA    1714
# 2           AA    1141
# 3           B6     725
# 4           DL     461
# ...        ...     ...
# 336771      9E    3393
# 336772      9E    3525
# 336773      MQ    3461
# 336774      MQ    3572
# 336775      MQ    3531
#
# [336776 rows x 2 columns]

# %%
df['new_dep_time'] = df['dep_time'].mul(2)
df
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
df.describe()

# %%
df.
